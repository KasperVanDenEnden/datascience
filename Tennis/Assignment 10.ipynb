# %%
import pandas as pd
tennis = pd.read_csv('atp_matches_2000.csv', sep=',')
tennis.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2000-717      Orlando    Clay         32             A      20000501
# 1   2000-717      Orlando    Clay         32             A      20000501
# 2   2000-717      Orlando    Clay         32             A      20000501
# 3   2000-717      Orlando    Clay         32             A      20000501
# 4   2000-717      Orlando    Clay         32             A      20000501
#
#    match_num  winner_id  winner_seed winner_entry  ... w_bpFaced l_ace  l_df  \
# 0          1     102179          NaN          NaN  ...      15.0  13.0   4.0
# 1          2     103602          NaN            Q  ...       6.0   0.0   0.0
# 2          3     103387          NaN          NaN  ...       0.0   2.0   2.0
# 3          4     101733          NaN          NaN  ...      12.0   4.0   6.0
# 4          5     101727          4.0          NaN  ...       1.0   0.0   3.0
#
# ...

# %%
tennis.corr()
# Out:
#                     draw_size  tourney_date  match_num  winner_id  \
# draw_size            1.000000     -0.050592   0.703977  -0.115389
# tourney_date        -0.050592      1.000000  -0.034212   0.009525
# match_num            0.703977     -0.034212   1.000000  -0.067362
# winner_id           -0.115389      0.009525  -0.067362   1.000000
# winner_seed          0.310857     -0.036634   0.152485   0.078525
# winner_ht            0.041811      0.023297   0.073012  -0.079961
# winner_age           0.070862      0.038206   0.031905  -0.828542
# winner_rank         -0.256718     -0.058041  -0.233200   0.176504
# winner_rank_points   0.191768      0.104290   0.299302  -0.065399
# loser_id            -0.134046     -0.019228  -0.086402   0.180623
# loser_seed           0.414563     -0.021667   0.259664  -0.039385
# loser_ht             0.023180      0.018609   0.065259  -0.016439
# loser_age            0.034306      0.012266   0.014398  -0.017895
# ...

# %% [markdown]
# # Minutes vs l_SvGms
# # l_SvGms vs w_SvGms
