# %% [markdown]
# # Bivariate analysis

# %%
import seaborn as sns

# %% [markdown]
# In univariate analysis we only looked at 1 variable (= 1 column) at a time. In bivariate analysis we will now look at the relation between two variables (= 2 columns).
#
# The type of analysis we can do will once again depend on the types of data of these 2 variables. We look look at:
# - Numerical VS Numerical.
# - Nummerical VS Categorical
# - Categorical VS Categorical

# %% [markdown]
# ## Numerical VS Numerical

# %% [markdown]
# Examples:
# - Body length VS Shoe size
# - Age VS Seconds it takes to run 1 kilometre
# - Country Unemployment rate VS Country Happiness Rating
# - Customer Revenue VS Customer Lifetime
# - Game Wishlists VS Game Purchases
# - Student grades VS Student attendance
# - ...

# %%
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ![](https://miro.medium.com/max/1000/1*Hh53mOF4Xy4eORjLilKOwA.png "Iris dataset")

# %% [markdown]
# Let's look at the relation between the sepal length and petal length. (Dutch: Kelkblad en bloemblad)

# %%
iris.plot(kind='scatter', x='sepal_length', y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# A useful statistic for calculating the linear relation between two variable is the **Pearson correlation**.
# The Pearson correlation measures the linear relation between two numerical variables. The result is a number between -1 and 1 where
# - -1 indicates a perfect negative linear relation
# - 0 indicates that there is no linear relation
# - 1 indicates a perfect positive linear relation

# %% [markdown]
# ![](https://www.spss-tutorials.com/img/correlation-coefficient-multiple-scatterplots.png "Pearson correlation examples")

# %% [markdown]
# ![](https://cdn1.byjus.com/wp-content/uploads/2019/06/word-image28.png "Pearson correlation formula")

# %%
iris[['sepal_length','petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.871754
# petal_length      0.871754      1.000000

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
irisCorrelations = iris.corr()
irisCorrelations.style.background_gradient(cmap='coolwarm', axis=None).format(precision=2)
# Out:
# <style type="text/css">
# #T_01d39_row0_col0, #T_01d39_row1_col1, #T_01d39_row2_col2, #T_01d39_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_01d39_row0_col1, #T_01d39_row1_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_01d39_row0_col2, #T_01d39_row2_col0 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_01d39_row0_col3, #T_01d39_row3_col0 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_01d39_row1_col2, #T_01d39_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_01d39_row1_col3, #T_01d39_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_01d39_row2_col3, #T_01d39_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_01d39">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01d39_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_01d39_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_01d39_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_01d39_level0_col3" class="col_heading level0 col3" >petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01d39_level0_row0" class="row_heading level0 row0" >sepal_length</th>
#       <td id="T_01d39_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_01d39_row0_col1" class="data row0 col1" >-0.12</td>
#       <td id="T_01d39_row0_col2" class="data row0 col2" >0.87</td>
#       <td id="T_01d39_row0_col3" class="data row0 col3" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_01d39_level0_row1" class="row_heading level0 row1" >sepal_width</th>
#       <td id="T_01d39_row1_col0" class="data row1 col0" >-0.12</td>
#       <td id="T_01d39_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_01d39_row1_col2" class="data row1 col2" >-0.43</td>
#       <td id="T_01d39_row1_col3" class="data row1 col3" >-0.37</td>
#     </tr>
#     <tr>
#       <th id="T_01d39_level0_row2" class="row_heading level0 row2" >petal_length</th>
#       <td id="T_01d39_row2_col0" class="data row2 col0" >0.87</td>
#       <td id="T_01d39_row2_col1" class="data row2 col1" >-0.43</td>
#       <td id="T_01d39_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_01d39_row2_col3" class="data row2 col3" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_01d39_level0_row3" class="row_heading level0 row3" >petal_width</th>
#       <td id="T_01d39_row3_col0" class="data row3 col0" >0.82</td>
#       <td id="T_01d39_row3_col1" class="data row3 col1" >-0.37</td>
#       <td id="T_01d39_row3_col2" class="data row3 col2" >0.96</td>
#       <td id="T_01d39_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
iris.plot(kind='scatter', x='sepal_width', y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>

# %%
import numpy as np

# %%
exampleData = pd.Series(range(100)) + 1
exampleDataNegative = -exampleData
exampleDataDouble = exampleData * 2
exampleDataSquared = exampleData ** 2
exampleDataRoot = exampleData ** 0.5

exampleDataExponential = 2 ** exampleData
exampleDataLog = np.log2(exampleData)

exampleDataWithSmallNoise = exampleData + np.random.randint(low=0, high=10, size=len(exampleData))
exampleDataWithMediumNoise = exampleData + np.random.randint(low=0, high=100, size=len(exampleData))
exampleDataWithHeavyNoise = exampleData + np.random.randint(low=0, high=1000, size=len(exampleData))

exampleDataFrame = pd.DataFrame({'original':exampleData, 'negative':exampleDataNegative, 'double':exampleDataDouble, 'squared':exampleDataSquared, 'root': exampleDataRoot, 'exp':exampleDataExponential, 'log':exampleDataLog, 'noiseSmall': exampleDataWithSmallNoise, 'noiseMedium': exampleDataWithMediumNoise, 'noiseHeavy':exampleDataWithHeavyNoise })

# %%
exampleDataFrame.head()
# Out:
#    original  negative  double  squared      root  exp       log  noiseSmall  \
# 0         1        -1       2        1  1.000000    2  0.000000           6
# 1         2        -2       4        4  1.414214    4  1.000000           2
# 2         3        -3       6        9  1.732051    8  1.584963           9
# 3         4        -4       8       16  2.000000   16  2.000000           9
# 4         5        -5      10       25  2.236068   32  2.321928          10
#
#    noiseMedium  noiseHeavy
# 0            4         135
# 1           89          20
# 2           17         681
# 3           24         771
# 4           10         724

# %%
exampleDataCorrelations = exampleDataFrame.corr()
exampleDataCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# C:\Users\Kaspe\AppData\Local\Temp\ipykernel_14184\2884428394.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   exampleDataCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_18e05_row0_col0, #T_18e05_row0_col2, #T_18e05_row0_col7, #T_18e05_row1_col1, #T_18e05_row2_col0, #T_18e05_row2_col2, #T_18e05_row2_col7, #T_18e05_row3_col3, #T_18e05_row4_col4, #T_18e05_row5_col5, #T_18e05_row6_col6, #T_18e05_row7_col0, #T_18e05_row7_col2, #T_18e05_row7_col7, #T_18e05_row8_col8, #T_18e05_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_18e05_row0_col1, #T_18e05_row1_col0, #T_18e05_row1_col2, #T_18e05_row1_col7, #T_18e05_row2_col1, #T_18e05_row7_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_18e05_row0_col3, #T_18e05_row2_col3, #T_18e05_row3_col0, #T_18e05_row3_col2 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_18e05_row0_col4, #T_18e05_row2_col4, #T_18e05_row4_col0, #T_18e05_row4_col2, #T_18e05_row4_col7, #T_18e05_row7_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_18e05_row0_col5, #T_18e05_row2_col5, #T_18e05_row3_col5, #T_18e05_row4_col5, #T_18e05_row5_col0, #T_18e05_row5_col2, #T_18e05_row5_col3, #T_18e05_row5_col4, #T_18e05_row5_col6, #T_18e05_row6_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_18e05_row0_col6, #T_18e05_row2_col6, #T_18e05_row6_col0, #T_18e05_row6_col2, #T_18e05_row6_col7, #T_18e05_row7_col6 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_18e05_row0_col8, #T_18e05_row2_col8, #T_18e05_row7_col8, #T_18e05_row8_col0, #T_18e05_row8_col2, #T_18e05_row8_col7 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_18e05_row0_col9, #T_18e05_row2_col9, #T_18e05_row7_col9, #T_18e05_row9_col0, #T_18e05_row9_col2, #T_18e05_row9_col7 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_18e05_row1_col3, #T_18e05_row3_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_18e05_row1_col4, #T_18e05_row4_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_18e05_row1_col5, #T_18e05_row5_col1, #T_18e05_row5_col8, #T_18e05_row5_col9, #T_18e05_row8_col5, #T_18e05_row9_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_18e05_row1_col6, #T_18e05_row6_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_18e05_row1_col8, #T_18e05_row8_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_18e05_row1_col9, #T_18e05_row9_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_18e05_row3_col4, #T_18e05_row4_col3 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_18e05_row3_col6, #T_18e05_row6_col3 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_18e05_row3_col7, #T_18e05_row4_col6, #T_18e05_row6_col4, #T_18e05_row7_col3 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_18e05_row3_col8, #T_18e05_row8_col3 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_18e05_row3_col9, #T_18e05_row9_col3 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_18e05_row4_col8, #T_18e05_row8_col4 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_18e05_row4_col9, #T_18e05_row9_col4 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_18e05_row5_col7, #T_18e05_row7_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_18e05_row6_col8, #T_18e05_row8_col6 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_18e05_row6_col9, #T_18e05_row9_col6 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_18e05_row8_col9, #T_18e05_row9_col8 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# </style>
# <table id="T_18e05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18e05_level0_col0" class="col_heading level0 col0" >original</th>
#       <th id="T_18e05_level0_col1" class="col_heading level0 col1" >negative</th>
#       <th id="T_18e05_level0_col2" class="col_heading level0 col2" >double</th>
#       <th id="T_18e05_level0_col3" class="col_heading level0 col3" >squared</th>
#       <th id="T_18e05_level0_col4" class="col_heading level0 col4" >root</th>
#       <th id="T_18e05_level0_col5" class="col_heading level0 col5" >exp</th>
#       <th id="T_18e05_level0_col6" class="col_heading level0 col6" >log</th>
#       <th id="T_18e05_level0_col7" class="col_heading level0 col7" >noiseSmall</th>
#       <th id="T_18e05_level0_col8" class="col_heading level0 col8" >noiseMedium</th>
#       <th id="T_18e05_level0_col9" class="col_heading level0 col9" >noiseHeavy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18e05_level0_row0" class="row_heading level0 row0" >original</th>
#       <td id="T_18e05_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_18e05_row0_col1" class="data row0 col1" >-1.00</td>
#       <td id="T_18e05_row0_col2" class="data row0 col2" >1.00</td>
#       <td id="T_18e05_row0_col3" class="data row0 col3" >0.97</td>
#       <td id="T_18e05_row0_col4" class="data row0 col4" >0.98</td>
#       <td id="T_18e05_row0_col5" class="data row0 col5" >-0.01</td>
#       <td id="T_18e05_row0_col6" class="data row0 col6" >0.90</td>
#       <td id="T_18e05_row0_col7" class="data row0 col7" >1.00</td>
#       <td id="T_18e05_row0_col8" class="data row0 col8" >0.70</td>
#       <td id="T_18e05_row0_col9" class="data row0 col9" >-0.14</td>
#     </tr>
#     <tr>
#       <th id="T_18e05_level0_row1" class="row_heading level0 row1" >negative</th>
#       <td id="T_18e05_row1_col0" class="data row1 col0" >-1.00</td>
#       <td id="T_18e05_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_18e05_row1_col2" class="data row1 col2" >-1.00</td>
#       <td id="T_18e05_row1_col3" class="data row1 col3" >-0.97</td>
#       <td id="T_18e05_row1_col4" class="data row1 col4" >-0.98</td>
#       <td id="T_18e05_row1_col5" class="data row1 col5" >0.01</td>
#       <td id="T_18e05_row1_col6" class="data row1 col6" >-0.90</td>
#       <td id="T_18e05_row1_col7" class="data row1 col7" >-1.00</td>
#       <td id="T_18e05_row1_col8" class="data row1 col8" >-0.70</td>
#       <td id="T_18e05_row1_col9" class="data row1 col9" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_18e05_level0_row2" class="row_heading level0 row2" >double</th>
#       <td id="T_18e05_row2_col0" class="data row2 col0" >1.00</td>
#       <td id="T_18e05_row2_col1" class="data row2 col1" >-1.00</td>
#       <td id="T_18e05_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_18e05_row2_col3" class="data row2 col3" >0.97</td>
#       <td id="T_18e05_row2_col4" class="data row2 col4" >0.98</td>
#       <td id="T_18e05_row2_col5" class="data row2 col5" >-0.01</td>
#       <td id="T_18e05_row2_col6" class="data row2 col6" >0.90</td>
#       <td id="T_18e05_row2_col7" class="data row2 col7" >1.00</td>
#       <td id="T_18e05_row2_col8" class="data row2 col8" >0.70</td>
#       <td id="T_18e05_row2_col9" class="data row2 col9" >-0.14</td>
#     </tr>
#     <tr>
#       <th id="T_18e05_level0_row3" class="row_heading level0 row3" >squared</th>
#       <td id="T_18e05_row3_col0" class="data row3 col0" >0.97</td>
#       <td id="T_18e05_row3_col1" class="data row3 col1" >-0.97</td>
#       <td id="T_18e05_row3_col2" class="data row3 col2" >0.97</td>
#       <td id="T_18e05_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_18e05_row3_col4" class="data row3 col4" >0.91</td>
#       <td id="T_18e05_row3_col5" class="data row3 col5" >-0.01</td>
#       <td id="T_18e05_row3_col6" class="data row3 col6" >0.78</td>
#       <td id="T_18e05_row3_col7" class="data row3 col7" >0.96</td>
#       <td id="T_18e05_row3_col8" class="data row3 col8" >0.68</td>
#       <td id="T_18e05_row3_col9" class="data row3 col9" >-0.14</td>
#     </tr>
#     <tr>
#       <th id="T_18e05_level0_row4" class="row_heading level0 row4" >root</th>
#       <td id="T_18e05_row4_col0" class="data row4 col0" >0.98</td>
#       <td id="T_18e05_row4_col1" class="data row4 col1" >-0.98</td>
#       <td id="T_18e05_row4_col2" class="data row4 col2" >0.98</td>
#       <td id="T_18e05_row4_col3" class="data row4 col3" >0.91</td>
#       <td id="T_18e05_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_18e05_row4_col5" class="data row4 col5" >-0.00</td>
#       <td id="T_18e05_row4_col6" class="data row4 col6" >0.96</td>
#       <td id="T_18e05_row4_col7" class="data row4 col7" >0.98</td>
#       <td id="T_18e05_row4_col8" class="data row4 col8" >0.69</td>

# %%
# Excluding a couple of columns because their values are too high to show in the same plot
exampleDataFrame.drop(['exp', 'squared' , 'noiseHeavy'], axis=1).plot(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Portfolio assignment 9
# 25 min: Perform a bivariate analysis on the columns with numerical data in the penguins dataset.
# - Use corr() on the DataFrame to calculate all the correlations. Use the code example above to show the correlation table with colors.
# - Look at the corrrelations. Do they match your expectations?
# - Show a scatter plot for
#  - The strongest positive correlation
#  - The strongest negative correlation
#  - The weakest correlation

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# # Penguins corrolation

# %%
penguinsDataCorrelations = penguins.corr()
penguinsDataCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# C:\Users\Kaspe\AppData\Local\Temp\ipykernel_14184\2436826163.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   penguinsDataCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_128d4_row0_col0, #T_128d4_row1_col1, #T_128d4_row2_col2, #T_128d4_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_128d4_row0_col1, #T_128d4_row1_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_128d4_row0_col2, #T_128d4_row2_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_128d4_row0_col3, #T_128d4_row3_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_128d4_row1_col2, #T_128d4_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_128d4_row1_col3, #T_128d4_row3_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_128d4_row2_col3, #T_128d4_row3_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_128d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_128d4_level0_col0" class="col_heading level0 col0" >bill_length_mm</th>
#       <th id="T_128d4_level0_col1" class="col_heading level0 col1" >bill_depth_mm</th>
#       <th id="T_128d4_level0_col2" class="col_heading level0 col2" >flipper_length_mm</th>
#       <th id="T_128d4_level0_col3" class="col_heading level0 col3" >body_mass_g</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_128d4_level0_row0" class="row_heading level0 row0" >bill_length_mm</th>
#       <td id="T_128d4_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_128d4_row0_col1" class="data row0 col1" >-0.24</td>
#       <td id="T_128d4_row0_col2" class="data row0 col2" >0.66</td>
#       <td id="T_128d4_row0_col3" class="data row0 col3" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_128d4_level0_row1" class="row_heading level0 row1" >bill_depth_mm</th>
#       <td id="T_128d4_row1_col0" class="data row1 col0" >-0.24</td>
#       <td id="T_128d4_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_128d4_row1_col2" class="data row1 col2" >-0.58</td>
#       <td id="T_128d4_row1_col3" class="data row1 col3" >-0.47</td>
#     </tr>
#     <tr>
#       <th id="T_128d4_level0_row2" class="row_heading level0 row2" >flipper_length_mm</th>
#       <td id="T_128d4_row2_col0" class="data row2 col0" >0.66</td>
#       <td id="T_128d4_row2_col1" class="data row2 col1" >-0.58</td>
#       <td id="T_128d4_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_128d4_row2_col3" class="data row2 col3" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_128d4_level0_row3" class="row_heading level0 row3" >body_mass_g</th>
#       <td id="T_128d4_row3_col0" class="data row3 col0" >0.60</td>
#       <td id="T_128d4_row3_col1" class="data row3 col1" >-0.47</td>
#       <td id="T_128d4_row3_col2" class="data row3 col2" >0.87</td>
#       <td id="T_128d4_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# In deze tabel is te zien dat er een sterke positieve corrolatie tussen de body_mass & flipper length. Op zich wel logisch dat wanneer een penguin groter is, zijn flippers langer zijn dan wanneer een penguin kleiner is. Verder is geen sterke corrolatie tussen de bill(beak) van een penguin met de body_mass.

# %%
# Excluding a couple of columns because their values are too high to show in the same plot
penguins.plot(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Strongest positive corrolation (0.87)

# %%
penguins.plot(kind='scatter', x='body_mass_g', y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# # The strongest negative correlation (-0,58)

# %%
penguins.plot(kind='scatter', x='bill_depth_mm', y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# # Weakest Corrolation (-0,24)

# %%
penguins.plot(kind='scatter', x='bill_depth_mm', y='bill_length_mm')
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %% [markdown]
# ![](https://www.galapagos.org/wp-content/uploads/2019/04/PenguinMeasurements_BLOGv3.png)

# %% [markdown]
# ![](https://i.imgur.com/0v1CGNV.png)

# %% [markdown]
# ### Portfolio assignment 10
# 15 min: Perform a bivariate analysis (Pearson correlation and scatter plot) on at least 1 combination of 2 columns with numeric data in the dataset that you chose in portfolio assignment 4. Does the correlation and scatter plot match your expectations? Add your answer to your notebook. Commit the Notebook to your portfolio when you're finished.

# %% [markdown]
# ![](https://i.imgur.com/0v1CGNV.png)

# %% [markdown]
# ## Numerical VS Categorical

# %% [markdown]
# Examples:
# - Monthly earnings VS Highest obtained degree
# - Body length VS Country of origin
# - Happiness rating VS Country of origin
# - Sales VS Account Manager.
# - Revenue VS Product Category
# - Revenue VS Game genre
# - Retention VS Software version
# - ...

# %% [markdown]
# In univariate analysis for numerical data we've looked at confidence intervals. We can use these to check if there are any signicant differences between categories.

# %% [markdown]
# You and I are are going to roll a 6-sided die. The numerical variable is the value we roll and the categorical variable is who rolled it. We know that in reality the average value of a 6-sided die is 3.5 (=(1+2+3+4+5+6)/6). We know that there is no skill involved, so who rolls the die should have no impact on the result. We each roll the die 3 times.
#     <img src="https://wherethewindsblow.com/wp-content/uploads/2015/07/JUMBO-Six-sided-white-dice.jpg" style="width: 300px;"/>

# %%
diceRolls = pd.DataFrame(data= {'Person': ['you', 'you', 'you', 'me','me','me'], 'Rolls': [6,3,6,2,4,2]})
diceRolls
# Out:
#   Person  Rolls
# 0    you      6
# 1    you      3
# 2    you      6
# 3     me      2
# 4     me      4
# 5     me      2

# %%
diceRolls.groupby(by="Person").mean()
# Out:
#            Rolls
# Person
# me      2.666667
# you     5.000000

# %% [markdown]
# Looks like you rolled an average value of 5 and I rolled an average value of ~2.7. Does this mean you are better at rolling dice than me?

# %%
sns.barplot(x="Person", y="Rolls", data=diceRolls)
# Out:
# <AxesSubplot:xlabel='Person', ylabel='Rolls'>

# %% [markdown]
# The confidence intervals overlap. This means that we can not yet be sure that you're a better dice roller than me. If we want the confidence intervals to become smaller, we'll need more data which means we need to do more dice rolls.

# %% [markdown]
# Let's look if there are significant difference between iris species.

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
sns.barplot(y="sepal_length", x="species", data=iris) 
# Add parameter ci if you want to change certainty of confidence interval. 
# For example ci = 99 for 99% certainty.
# The default is 95%
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(y="sepal_width", x="species", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.barplot(y="petal_length", x="species", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.barplot(y="petal_width", x="species", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %% [markdown]
# ### Portfolio assignment 11
# 20 min: Do a Numerical VS Categorical bivariate analysis on the penguins dataset.
# - Choose one of the categorical columns: species, island or sex
# - use .groupby('<columnname>').mean() too look at the means of the numerical columns. Does it look like there is a difference between categories?
# - Use the seaborn barplot to plot the mean and confidence. Create this plot for each of the numerical columns (bill_length_mm	bill_depth_mm, flipper_length_mm, body_mass_g)
# - For each of the plots, write a conclusion: Is there a statistically significant difference for this numerical column for each category?
# - Optional: Repeat this proces for the other two categorical columns

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.groupby(by="species").mean()
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie          38.791391      18.346358         189.953642  3700.662252
# Chinstrap       48.833824      18.420588         195.823529  3733.088235
# Gentoo          47.504878      14.982114         217.186992  5076.016260

# %% [markdown]
# # Bill length vs Species

# %%
sns.barplot(y="bill_length_mm", x="species", data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %% [markdown]
# # Bill depth vs Species

# %%
sns.barplot(y="bill_depth_mm", x="species", data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_depth_mm'>

# %% [markdown]
# # Flipper length vs Species

# %%
sns.barplot(y="flipper_length_mm", x="species", data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# # Body mass vs Species

# %%
sns.barplot(y="body_mass_g", x="species", data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ![](https://www.galapagos.org/wp-content/uploads/2019/04/PenguinMeasurements_BLOGv3.png)

# %% [markdown]
# ![](https://i.imgur.com/0v1CGNV.png)

# %% [markdown]
# ### Portfolio assignment 12
# 30 min: Perform a bivariate analysis on at least 3 combinations of a numerical column with a categorical column in the dataset that you chose in portfolio assignment 4. Use <em>.groupby('columnname').mean()</em> to calculate the means. Is there a difference between categories? Then use seaborn barplots to check if there is a statistically significant difference.

# %% [markdown]
# ![](https://i.imgur.com/0v1CGNV.png)

# %% [markdown]
# ## Categorical VS Categorical

# %% [markdown]
# Examples:
# - Inbound channel VS Type of customer
# - Education VS Job function
# - Region of citizen VS Who the citizen votes for
# - Color shirt of crew member in Stat Trek VS Does the crew member survive? (https://statisticsbyjim.com/hypothesis-testing/chi-square-test-independence-example/)
# - Customer newsletter subscription (Yes/No) VS Custom churn (Yes/No)
# - Penguin island VS Penguin species
# - ...

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.species.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![](data:image/jpeg;base64,...)

# %%
penguins['island'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
def create_contingency_table(dataset, column1, column2):
    return dataset.groupby([column1, column2]).size().unstack(column1, fill_value=0)

# %%
penguinsContingencyTable = create_contingency_table(penguins, 'species','island')

# %%
penguinsContingencyTable.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='island'>

# %%
from scipy.stats import chi2_contingency
def check_cat_vs_cat_correlation(dataset, column1, column2):
    contingency_table = create_contingency_table(dataset, column1, column2)
    chi2 = chi2_contingency(contingency_table)
    p_value = chi2[1]
    odds_of_correlation = 1 - p_value
    print(f"The odds of a correlation between {column1} and {column2} is {odds_of_correlation * 100}% (Based on a p value of {p_value}).")
    print("This percentage needs to be at least 95% for a significant correlation.")

# %%
check_cat_vs_cat_correlation(penguins, 'species','island')
# Out:
# The odds of a correlation between species and island is 100.0% (Based on a p value of 1.3545738297192517e-63).
# This percentage needs to be at least 95% for a significant correlation.

# %% [markdown]
# ![](https://1000logos.net/wp-content/uploads/2021/01/Suitmarks-of-playing-cards.jpg)

# %%
cardThrows = pd.DataFrame(data= {'Person': ['you', 'you', 'you', 'me','me','me'], 'Throws': ['spades','hearts','clubs','spades', 'hearts','diamonds']})

# %%
cardThrows
# Out:
#   Person    Throws
# 0    you    spades
# 1    you    hearts
# 2    you     clubs
# 3     me    spades
# 4     me    hearts
# 5     me  diamonds

# %%
contingencyTableCardThrows = create_contingency_table(cardThrows, 'Person','Throws')

# %%
contingencyTableCardThrows.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Throws'>

# %%
check_cat_vs_cat_correlation(cardThrows, 'Person','Throws')
# Out:
# The odds of a correlation between Person and Throws is 42.75932955291202% (Based on a p value of 0.5724067044708798).
# This percentage needs to be at least 95% for a significant correlation.

# %% [markdown]
# ![](https://miro.medium.com/max/532/1*S8rfFkmLhDbOz4RGNwuz6g.png)

# %%
# Change the numberOfRolls and low & high of each player to see the impact on the chi-square test.
numberOfThrows = 30
person1Throws= pd.Series( np.random.choice(['spades','hearts','clubs', 'diamonds'], size=numberOfThrows ))
person2Throws= pd.Series( np.random.choice(['spades','hearts','clubs'], size=numberOfThrows ))

cardThrows2 = pd.DataFrame({
    'Person':pd.concat([pd.Series(['Person1']*numberOfThrows),pd.Series(['Person2']*numberOfThrows)]),
    'Throws':pd.concat([person1Throws,person2Throws])
})
cardThrows2.head()
# Out:
#     Person    Throws
# 0  Person1    hearts
# 1  Person1     clubs
# 2  Person1    hearts
# 3  Person1    spades
# 4  Person1  diamonds

# %%
contingencyTableCardThrows2 = create_contingency_table(cardThrows2, 'Person','Throws')

# %%
contingencyTableCardThrows2.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Throws'>

# %%
check_cat_vs_cat_correlation(cardThrows2, 'Person','Throws')
# Out:
# The odds of a correlation between Person and Throws is 97.64697834341825% (Based on a p value of 0.023530216565817403).
# This percentage needs to be at least 95% for a significant correlation.

# %% [markdown]
# ### Portfolio assignment 13
# 10 min: Do a bivariate analysis on the penguins dataset for the following combination of columns:
# - species VS sex
# - island VS sex
#
# For this bivariate analysis, at least perform the following tasks:
# - Do you expect their to be a correlation between the two columns?
# - Create a contingency table. Do you observe different ratios between categories here?
# - Create a bar plot for this contingency table. Do you observe different ratios between categories here?
# - Do a chi-squared test. What does the result say? What's the chance of there being a correlation between the two columns?
#
# ![](https://i.imgur.com/0v1CGNV.png)

# %%
penguinsSvsSTable = create_contingency_table(penguins, 'species','sex')
penguinsIvsSTable = create_contingency_table(penguins, 'island','sex')

# %% [markdown]
# # Species vs Sex

# %%
penguinsSvsSTable.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
check_cat_vs_cat_correlation(penguins, 'species','sex')
# Out:
# The odds of a correlation between species and sex is 2.4010631023415385% (Based on a p value of 0.9759893689765846).
# This percentage needs to be at least 95% for a significant correlation.

# %% [markdown]
# # Island vs Sex

# %%
penguinsIvsSTable.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
check_cat_vs_cat_correlation(penguins, 'island','sex')
# Out:
# The odds of a correlation between island and sex is 2.8388770718934975% (Based on a p value of 0.971611229281065).
# This percentage needs to be at least 95% for a significant correlation.

# %% [markdown]
# ### Portfolio assignment 14
# Perform a bivariate analysis on at least 1 combination of 2 columns with categorical data in the dataset that you chose in portfolio assignment 4.
# - Do you expect their to be a correlation between the two columns?
# - Create a contingency table. Do you observe different ratios between categories here?
# - Create a bar plot for this contingency table. Do you observe different ratios between categories here?
# - Do a chi-squared test. What does the result say? What's the chance of there being a correlation between the two columns?
#
# ![](https://i.imgur.com/0v1CGNV.png)
