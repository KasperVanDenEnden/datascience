# %%
import pandas as pd
anime = pd.read_csv('Anime.csv')
anime.head()
# Out:
#       ID                             Title                          English  \
# 0  16498                Shingeki no Kyojin                  Attack on Titan
# 1   1535                        Death Note                       Death Note
# 2   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist Brotherhood
# 3  30276                     One Punch Man                    One Punch Man
# 4  11757                  Sword Art Online                 Sword Art Online
#
#                                             Synopsis Type  Episodes  \
# 0  Centuries ago, mankind was slaughtered to near...   TV        25
# 1  Brutal murders, petty thefts, and senseless vi...   TV        37
# 2  After a horrific alchemy experiment goes wrong...   TV        64
# 3  The seemingly unimpressive Saitama has a rathe...   TV        12
# 4  Ever since the release of the innovative Nerve...   TV        25
#
#             Status Start_Aired  End_Aired    Premiered  ...  \
# ...

# %% [markdown]
# # Portfolio assignment 10
# 15 min:
#
# Perform a bivariate analysis (Pearson correlation and scatter plot) on at least 1 combination of 2 columns with numeric data in the dataset that you chose in portfolio assignment 4. Does the correlation and scatter plot match your expectations? Add your answer to your notebook. Commit the Notebook to your portfolio when you're finished.

# %% [markdown]
# # Height (m) VS Weight (kg)

# %%
animeScoreEpisodes = anime[['Score','Episodes']].dropna().corr()
animeScoreEpisodes.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# C:\Users\Kaspe\AppData\Local\Temp\ipykernel_10932\2850328475.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   animeScoreEpisodes.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_5c109_row0_col0, #T_5c109_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5c109_row0_col1, #T_5c109_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5c109">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c109_level0_col0" class="col_heading level0 col0" >Score</th>
#       <th id="T_5c109_level0_col1" class="col_heading level0 col1" >Episodes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c109_level0_row0" class="row_heading level0 row0" >Score</th>
#       <td id="T_5c109_row0_col0" class="data row0 col0" >1.00</td>
# ...

# %%
anime.plot(kind='scatter', x='Score', y='Episodes')
# Out:
# <AxesSubplot:xlabel='Score', ylabel='Episodes'>

# %% [markdown]
# # Numerical Corr Table

# %%
AnimeNumerical = anime[['Episodes','Duration_Minutes','Score','Scored_Users','Ranked','Popularity','Members','Favorites']].dropna().corr()
AnimeNumerical.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# C:\Users\Kaspe\AppData\Local\Temp\ipykernel_10932\4154488088.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   AnimeNumerical.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_26d44_row0_col0, #T_26d44_row1_col1, #T_26d44_row2_col2, #T_26d44_row3_col3, #T_26d44_row4_col4, #T_26d44_row5_col5, #T_26d44_row6_col6, #T_26d44_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_26d44_row0_col1, #T_26d44_row0_col4, #T_26d44_row1_col0, #T_26d44_row4_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_26d44_row0_col2, #T_26d44_row1_col3, #T_26d44_row2_col0, #T_26d44_row3_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_26d44_row0_col3, #T_26d44_row0_col6, #T_26d44_row3_col0, #T_26d44_row6_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_26d44_row0_col5, #T_26d44_row5_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# ...

# %% [markdown]
# Ik had inderdaad lage corrolaties verwacht als het gaat met betrekking tot episodes en duration_minutes. Dit komt omdat veel anime's dezelfde aantal afleveringen bevatten en afleveringen voor anime standaard rond de 20-25 minuten zijn. Daarom zal dit geen oorzaak zijn voor andere gegevens.
# Verder is het wel logisch dat er een sterke corrolatie is tussen score en Ranked. Hoe hoger de score hoe hoger je geranked staat natuurlijk

# %% [markdown]
# # Score & Ranked (-0,98)

# %%
anime.plot(kind='scatter', x='Score', y='Ranked')
# Out:
# <AxesSubplot:xlabel='Score', ylabel='Ranked'>

# %% [raw]
# Spreekt voor zich dat als je een hogere score haalt je ook hoger (in dit geval een lager getal) scoort

# %% [markdown]
# # Members & Scored Users (0,89)

# %%
anime.plot(kind='scatter', x='Members', y='Scored_Users')
# Out:
# <AxesSubplot:xlabel='Members', ylabel='Scored_Users'>

# %% [markdown]
# # Ranked & Popularity (0,73)

# %%
anime.plot(kind='scatter', x='Ranked', y='Popularity')
# Out:
# <AxesSubplot:xlabel='Ranked', ylabel='Popularity'>

# %% [markdown]
# Ondanks dat de corrolatie lager licht zie je toch wel een verticale scheiding rond de 130000 ranked. Er is dus een groep aan anime die laag ranking hebben en toch veel gekeken zijn.

# %% [markdown]
# # Favorites & Members (0.79)

# %%
anime.plot(kind='scatter', x='Favorites', y='Members')
# Out:
# <AxesSubplot:xlabel='Favorites', ylabel='Members'>

# %% [markdown]
# Ondanks de iets lagere corrolatie is er dus een duidelijke cluster te zien met een aantal uitschieters naar rechtsboven
